# %%
# ============================================
# FYP MODEL IMPROVEMENT EXPERIMENTS (CORRECTED)
# ============================================
# All models are evaluated under identical conditions:
# - 3-Fold TimeSeriesSplit Cross-Validation
# - Same training data
# - Same test set evaluation
# - Same metrics reported

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score, recall_score, 
    f1_score, classification_report, confusion_matrix
)
from sklearn.feature_selection import SelectFromModel
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
print("="*70)
print("FYP MODEL IMPROVEMENT EXPERIMENTS (CORRECTED)")
print("All experiments use identical evaluation conditions")
print("="*70)

# ============================================
# STEP 1: LOAD DATA AND SETUP
# ============================================

print("\n[Step 1] Loading data and setting up evaluation framework...")

# Load data from Task 12-14
train_df = pd.read_csv('data/ml/train_data.csv', parse_dates=['Snapshot_Date'])
val_df = pd.read_csv('data/ml/val_data.csv', parse_dates=['Snapshot_Date'])
test_df = pd.read_csv('data/ml/test_data.csv', parse_dates=['Snapshot_Date'])
feature_cols = pd.read_csv('data/ml/feature_columns.csv')['Feature'].tolist()

# Sort training data chronologically
train_df_sorted = train_df.sort_values('Snapshot_Date').reset_index(drop=True)

# Prepare X and y
X_train = train_df_sorted[feature_cols].copy()
y_train = train_df_sorted['Label'].copy()
X_val = val_df[feature_cols].copy()
y_val = val_df['Label'].copy()
X_test = test_df[feature_cols].copy()
y_test = test_df['Label'].copy()

# Fill missing values
train_medians = X_train.median()
X_train = X_train.fillna(train_medians)
X_val = X_val.fillna(train_medians)
X_test = X_test.fillna(train_medians)

# Create TimeSeriesSplit (same as Task 13)
N_SPLITS = 3
tscv = TimeSeriesSplit(n_splits=N_SPLITS)

print(f"✓ Data loaded:")
print(f"  Training: {X_train.shape}")
print(f"  Validation: {X_val.shape}")
print(f"  Test: {X_test.shape}")
print(f"  Features: {len(feature_cols)}")
print(f"  Cross-validation: {N_SPLITS}-Fold TimeSeriesSplit")

# ============================================
# STEP 2: DEFINE STANDARDIZED EVALUATION FUNCTION
# ============================================

print("\n[Step 2] Defining standardized evaluation function...")

def evaluate_model(model, X_train, y_train, X_test, y_test, tscv, model_name):
    """
    Evaluate a model using both cross-validation and test set.
    Ensures all models are evaluated under identical conditions.
    
    Returns:
        dict: Dictionary containing all metrics
    """
    results = {'Model': model_name}
    
    # ===== CROSS-VALIDATION =====
    # Get CV scores for multiple metrics
    cv_accuracy = cross_val_score(model, X_train, y_train, cv=tscv, scoring='accuracy')
    cv_precision = cross_val_score(model, X_train, y_train, cv=tscv, scoring='precision')
    cv_recall = cross_val_score(model, X_train, y_train, cv=tscv, scoring='recall')
    cv_f1 = cross_val_score(model, X_train, y_train, cv=tscv, scoring='f1')
    cv_roc_auc = cross_val_score(model, X_train, y_train, cv=tscv, scoring='roc_auc')
    
    # Store CV results
    results['CV_Accuracy_Mean'] = cv_accuracy.mean()
    results['CV_Accuracy_Std'] = cv_accuracy.std()
    results['CV_Precision_Mean'] = cv_precision.mean()
    results['CV_Precision_Std'] = cv_precision.std()
    results['CV_Recall_Mean'] = cv_recall.mean()
    results['CV_Recall_Std'] = cv_recall.std()
    results['CV_F1_Mean'] = cv_f1.mean()
    results['CV_F1_Std'] = cv_f1.std()
    results['CV_ROC_AUC_Mean'] = cv_roc_auc.mean()
    results['CV_ROC_AUC_Std'] = cv_roc_auc.std()
    
    # ===== TRAIN ON FULL TRAINING SET =====
    model.fit(X_train, y_train)
    
    # ===== TEST SET EVALUATION =====
    y_test_pred = model.predict(X_test)
    y_test_proba = model.predict_proba(X_test)[:, 1]
    
    results['Test_Accuracy'] = accuracy_score(y_test, y_test_pred)
    results['Test_Precision'] = precision_score(y_test, y_test_pred, zero_division=0)
    results['Test_Recall'] = recall_score(y_test, y_test_pred, zero_division=0)
    results['Test_F1'] = f1_score(y_test, y_test_pred, zero_division=0)
    results['Test_ROC_AUC'] = roc_auc_score(y_test, y_test_proba)
    
    # ===== GENERALIZATION GAP =====
    # Difference between CV and Test performance (indicates overfitting)
    results['Generalization_Gap'] = results['CV_ROC_AUC_Mean'] - results['Test_ROC_AUC']
    
    return results, model

def print_evaluation_results(results):
    """Print formatted evaluation results."""
    print(f"\n  Cross-Validation Results ({N_SPLITS}-Fold TimeSeriesSplit):")
    print(f"    Accuracy:  {results['CV_Accuracy_Mean']:.4f} ± {results['CV_Accuracy_Std']:.4f}")
    print(f"    Precision: {results['CV_Precision_Mean']:.4f} ± {results['CV_Precision_Std']:.4f}")
    print(f"    Recall:    {results['CV_Recall_Mean']:.4f} ± {results['CV_Recall_Std']:.4f}")
    print(f"    F1 Score:  {results['CV_F1_Mean']:.4f} ± {results['CV_F1_Std']:.4f}")
    print(f"    ROC-AUC:   {results['CV_ROC_AUC_Mean']:.4f} ± {results['CV_ROC_AUC_Std']:.4f}")
    
    print(f"\n  Test Set Results:")
    print(f"    Accuracy:  {results['Test_Accuracy']:.4f}")
    print(f"    Precision: {results['Test_Precision']:.4f}")
    print(f"    Recall:    {results['Test_Recall']:.4f}")
    print(f"    F1 Score:  {results['Test_F1']:.4f}")
    print(f"    ROC-AUC:   {results['Test_ROC_AUC']:.4f}")
    
    print(f"\n  Generalization Gap (CV - Test ROC-AUC): {results['Generalization_Gap']:.4f}")
    if results['Generalization_Gap'] > 0.05:
        print("    ⚠️ Warning: Significant overfitting detected")
    else:
        print("    ✓ Good generalization")

print("✓ Standardized evaluation function defined")

# Store all results
all_results = []

# ============================================
# EXPERIMENT 0: BASELINE RANDOM FOREST
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 0: BASELINE RANDOM FOREST")
print("="*70)

baseline_rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_leaf=5,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

print("\nModel Configuration:")
print(f"  n_estimators: 100")
print(f"  max_depth: 10")
print(f"  min_samples_leaf: 5")
print(f"  class_weight: balanced")

baseline_results, baseline_model_trained = evaluate_model(
    baseline_rf, X_train, y_train, X_test, y_test, tscv, 'Baseline RF'
)
all_results.append(baseline_results)
print_evaluation_results(baseline_results)

# Store baseline ROC-AUC for comparison
baseline_cv_roc = baseline_results['CV_ROC_AUC_Mean']
baseline_test_roc = baseline_results['Test_ROC_AUC']

# ============================================
# EXPERIMENT 1: IMPROVED FEATURES
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 1: IMPROVED FEATURES")
print("="*70)

# Identify and remove problematic absolute features
absolute_features = ['Price', 'SMA_50', 'SMA_200', 'Avg_Volume_3M', 'Market_Cap']
existing_absolute = [f for f in absolute_features if f in feature_cols]

print(f"\nRemoving absolute features that may cause overfitting:")
print(f"  {existing_absolute}")

# Create improved feature set
improved_features = [f for f in feature_cols if f not in absolute_features]

print(f"\nOriginal features: {len(feature_cols)}")
print(f"Improved features: {len(improved_features)}")

# Prepare improved data
X_train_improved = X_train[improved_features].copy()
X_test_improved = X_test[improved_features].copy()

# Same model configuration as baseline
rf_improved_feat = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_leaf=5,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

improved_feat_results, rf_improved_feat_trained = evaluate_model(
    rf_improved_feat, X_train_improved, y_train, X_test_improved, y_test, tscv, 'RF - Improved Features'
)
all_results.append(improved_feat_results)
print_evaluation_results(improved_feat_results)

print(f"\n  Comparison to Baseline:")
print(f"    CV ROC-AUC:   {improved_feat_results['CV_ROC_AUC_Mean']:.4f} vs {baseline_cv_roc:.4f} ({(improved_feat_results['CV_ROC_AUC_Mean'] - baseline_cv_roc)*100:+.2f}%)")
print(f"    Test ROC-AUC: {improved_feat_results['Test_ROC_AUC']:.4f} vs {baseline_test_roc:.4f} ({(improved_feat_results['Test_ROC_AUC'] - baseline_test_roc)*100:+.2f}%)")

# ============================================
# EXPERIMENT 2: HYPERPARAMETER TUNING
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 2: HYPERPARAMETER TUNING (GridSearchCV)")
print("="*70)

# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 7, 10],
    'min_samples_leaf': [5, 10, 15],
    'max_features': ['sqrt', 'log2']
}

print(f"\nParameter grid:")
for param, values in param_grid.items():
    print(f"  {param}: {values}")

# Base model
rf_base = RandomForestClassifier(
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

# Grid search with TimeSeriesSplit
print("\nRunning GridSearchCV with TimeSeriesSplit (this may take a few minutes)...")
grid_search = GridSearchCV(
    estimator=rf_base,
    param_grid=param_grid,
    cv=tscv,
    scoring='roc_auc',
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_search.fit(X_train, y_train)

print(f"\n✓ Best Parameters: {grid_search.best_params_}")
print(f"✓ Best CV ROC-AUC: {grid_search.best_score_:.4f}")

# Evaluate best model using our standardized function
best_rf_params = grid_search.best_params_
rf_tuned = RandomForestClassifier(
    **best_rf_params,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

tuned_results, rf_tuned_trained = evaluate_model(
    rf_tuned, X_train, y_train, X_test, y_test, tscv, 'RF - Tuned'
)
all_results.append(tuned_results)
print_evaluation_results(tuned_results)

print(f"\n  Comparison to Baseline:")
print(f"    CV ROC-AUC:   {tuned_results['CV_ROC_AUC_Mean']:.4f} vs {baseline_cv_roc:.4f} ({(tuned_results['CV_ROC_AUC_Mean'] - baseline_cv_roc)*100:+.2f}%)")
print(f"    Test ROC-AUC: {tuned_results['Test_ROC_AUC']:.4f} vs {baseline_test_roc:.4f} ({(tuned_results['Test_ROC_AUC'] - baseline_test_roc)*100:+.2f}%)")

# ============================================
# EXPERIMENT 3: ALGORITHM COMPARISON
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 3: ALGORITHM COMPARISON")
print("="*70)

print("\nComparing different ML algorithms under identical conditions...")

# Define models to compare
comparison_models = {
    'Logistic Regression': LogisticRegression(
        class_weight='balanced',
        max_iter=1000,
        random_state=42
    ),
    'Gradient Boosting': GradientBoostingClassifier(
        n_estimators=100,
        max_depth=5,
        min_samples_leaf=10,
        random_state=42
    ),
    'AdaBoost': AdaBoostClassifier(
        n_estimators=100,
        random_state=42
    )
}

for model_name, model in comparison_models.items():
    print(f"\n--- {model_name} ---")
    
    model_results, trained_model = evaluate_model(
        model, X_train, y_train, X_test, y_test, tscv, model_name
    )
    all_results.append(model_results)
    print_evaluation_results(model_results)
    
    print(f"\n  Comparison to Baseline:")
    print(f"    CV ROC-AUC:   {model_results['CV_ROC_AUC_Mean']:.4f} vs {baseline_cv_roc:.4f} ({(model_results['CV_ROC_AUC_Mean'] - baseline_cv_roc)*100:+.2f}%)")
    print(f"    Test ROC-AUC: {model_results['Test_ROC_AUC']:.4f} vs {baseline_test_roc:.4f} ({(model_results['Test_ROC_AUC'] - baseline_test_roc)*100:+.2f}%)")
    
    # Store trained model for potential later use
    comparison_models[model_name] = trained_model

# ============================================
# EXPERIMENT 4: REGULARIZED RANDOM FOREST
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 4: REGULARIZED RANDOM FOREST")
print("="*70)

rf_regularized = RandomForestClassifier(
    n_estimators=50,           # Fewer trees
    max_depth=5,               # Shallower (was 10)
    min_samples_leaf=20,       # More samples per leaf (was 5)
    min_samples_split=30,      # More samples to split
    max_features=0.3,          # Only 30% of features per tree
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

print("\nRegularization settings (vs Baseline):")
print("  n_estimators:     50  (was 100)")
print("  max_depth:        5   (was 10)")
print("  min_samples_leaf: 20  (was 5)")
print("  min_samples_split: 30 (new)")
print("  max_features:     0.3 (new)")

regularized_results, rf_regularized_trained = evaluate_model(
    rf_regularized, X_train, y_train, X_test, y_test, tscv, 'RF - Regularized'
)
all_results.append(regularized_results)
print_evaluation_results(regularized_results)

print(f"\n  Comparison to Baseline:")
print(f"    CV ROC-AUC:   {regularized_results['CV_ROC_AUC_Mean']:.4f} vs {baseline_cv_roc:.4f} ({(regularized_results['CV_ROC_AUC_Mean'] - baseline_cv_roc)*100:+.2f}%)")
print(f"    Test ROC-AUC: {regularized_results['Test_ROC_AUC']:.4f} vs {baseline_test_roc:.4f} ({(regularized_results['Test_ROC_AUC'] - baseline_test_roc)*100:+.2f}%)")

# ============================================
# EXPERIMENT 5: COMBINED IMPROVEMENTS
# ============================================

print("\n" + "="*70)
print("EXPERIMENT 5: COMBINED IMPROVEMENTS")
print("="*70)

print("\nCombining: Improved Features + Moderate Regularization")

rf_combined = RandomForestClassifier(
    n_estimators=100,
    max_depth=7,               # Moderate depth
    min_samples_leaf=10,       # Moderate regularization
    min_samples_split=15,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

print("\nCombined model settings:")
print("  Features:         Improved (removed absolute features)")
print("  n_estimators:     100")
print("  max_depth:        7   (moderate)")
print("  min_samples_leaf: 10  (moderate)")
print("  min_samples_split: 15")
print("  max_features:     sqrt")

combined_results, rf_combined_trained = evaluate_model(
    rf_combined, X_train_improved, y_train, X_test_improved, y_test, tscv, 'RF - Combined'
)
all_results.append(combined_results)
print_evaluation_results(combined_results)

print(f"\n  Comparison to Baseline:")
print(f"    CV ROC-AUC:   {combined_results['CV_ROC_AUC_Mean']:.4f} vs {baseline_cv_roc:.4f} ({(combined_results['CV_ROC_AUC_Mean'] - baseline_cv_roc)*100:+.2f}%)")
print(f"    Test ROC-AUC: {combined_results['Test_ROC_AUC']:.4f} vs {baseline_test_roc:.4f} ({(combined_results['Test_ROC_AUC'] - baseline_test_roc)*100:+.2f}%)")

# ============================================
# STEP 3: COMPREHENSIVE RESULTS COMPARISON
# ============================================

print("\n" + "="*70)
print("COMPREHENSIVE RESULTS COMPARISON")
print("="*70)

# Create results DataFrame
results_df = pd.DataFrame(all_results)

# Calculate improvement over baseline
results_df['CV_vs_Baseline'] = ((results_df['CV_ROC_AUC_Mean'] - baseline_cv_roc) * 100).apply(lambda x: f"{x:+.2f}%")
results_df['Test_vs_Baseline'] = ((results_df['Test_ROC_AUC'] - baseline_test_roc) * 100).apply(lambda x: f"{x:+.2f}%")

# Sort by Test ROC-AUC
results_df_sorted = results_df.sort_values('Test_ROC_AUC', ascending=False).reset_index(drop=True)
results_df_sorted['Rank'] = range(1, len(results_df_sorted) + 1)

# ===== TABLE 1: CROSS-VALIDATION RESULTS =====
print("\n" + "="*70)
print("TABLE 1: CROSS-VALIDATION RESULTS (3-Fold TimeSeriesSplit)")
print("="*70)

cv_cols = ['Rank', 'Model', 'CV_Accuracy_Mean', 'CV_Precision_Mean', 'CV_Recall_Mean', 'CV_F1_Mean', 'CV_ROC_AUC_Mean', 'CV_ROC_AUC_Std']
cv_display = results_df_sorted[cv_cols].copy()
cv_display.columns = ['Rank', 'Model', 'Accuracy', 'Precision', 'Recall', 'F1', 'ROC-AUC', 'Std']

# Format numbers
for col in ['Accuracy', 'Precision', 'Recall', 'F1', 'ROC-AUC', 'Std']:
    cv_display[col] = cv_display[col].apply(lambda x: f"{x:.4f}")

print(cv_display.to_string(index=False))

# ===== TABLE 2: TEST SET RESULTS =====
print("\n" + "="*70)
print("TABLE 2: TEST SET RESULTS")
print("="*70)

test_cols = ['Rank', 'Model', 'Test_Accuracy', 'Test_Precision', 'Test_Recall', 'Test_F1', 'Test_ROC_AUC', 'Test_vs_Baseline']
test_display = results_df_sorted[test_cols].copy()
test_display.columns = ['Rank', 'Model', 'Accuracy', 'Precision', 'Recall', 'F1', 'ROC-AUC', 'vs Baseline']

# Format numbers
for col in ['Accuracy', 'Precision', 'Recall', 'F1', 'ROC-AUC']:
    test_display[col] = test_display[col].apply(lambda x: f"{x:.4f}")

print(test_display.to_string(index=False))

# ===== TABLE 3: GENERALIZATION ANALYSIS =====
print("\n" + "="*70)
print("TABLE 3: GENERALIZATION ANALYSIS (Overfitting Detection)")
print("="*70)

gen_cols = ['Rank', 'Model', 'CV_ROC_AUC_Mean', 'Test_ROC_AUC', 'Generalization_Gap']
gen_display = results_df_sorted[gen_cols].copy()
gen_display.columns = ['Rank', 'Model', 'CV ROC-AUC', 'Test ROC-AUC', 'Gap (CV - Test)']

# Format numbers
gen_display['CV ROC-AUC'] = gen_display['CV ROC-AUC'].apply(lambda x: f"{x:.4f}")
gen_display['Test ROC-AUC'] = gen_display['Test ROC-AUC'].apply(lambda x: f"{x:.4f}")
gen_display['Gap (CV - Test)'] = gen_display['Gap (CV - Test)'].apply(lambda x: f"{x:+.4f}")

print(gen_display.to_string(index=False))

print("\nInterpretation:")
print("  - Positive gap: Model performs better on CV than test (overfitting)")
print("  - Negative gap: Model performs better on test than CV (good generalization)")
print("  - Gap > 0.05: Significant overfitting concern")

# ===== IDENTIFY BEST MODEL =====
best_model_idx = results_df_sorted['Test_ROC_AUC'].idxmax()
best_model_name = results_df_sorted.loc[best_model_idx, 'Model']
best_cv_roc = results_df_sorted.loc[best_model_idx, 'CV_ROC_AUC_Mean']
best_test_roc = results_df_sorted.loc[best_model_idx, 'Test_ROC_AUC']

print("\n" + "="*70)
print("🏆 BEST MODEL IDENTIFICATION")
print("="*70)
print(f"\n  Best Model:     {best_model_name}")
print(f"  CV ROC-AUC:     {best_cv_roc:.4f}")
print(f"  Test ROC-AUC:   {best_test_roc:.4f}")
print(f"  Improvement:    {(best_test_roc - baseline_test_roc)*100:+.2f}% over baseline")

# ============================================
# STEP 4: VISUALIZATION
# ============================================

print("\n[Step 4] Creating visualizations...")

fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# Plot 1: CV vs Test ROC-AUC Comparison
ax1 = axes[0, 0]
x = np.arange(len(results_df_sorted))
width = 0.35
bars1 = ax1.bar(x - width/2, results_df_sorted['CV_ROC_AUC_Mean'], width, label='CV ROC-AUC', color='steelblue', alpha=0.8)
bars2 = ax1.bar(x + width/2, results_df_sorted['Test_ROC_AUC'], width, label='Test ROC-AUC', color='darkorange', alpha=0.8)
ax1.axhline(y=0.5, color='red', linestyle='--', label='Random Baseline')
ax1.set_xlabel('Model')
ax1.set_ylabel('ROC-AUC')
ax1.set_title('Cross-Validation vs Test ROC-AUC', fontweight='bold')
ax1.set_xticks(x)
ax1.set_xticklabels(results_df_sorted['Model'], rotation=45, ha='right')
ax1.legend()
ax1.set_ylim(0.4, 0.75)
ax1.grid(True, alpha=0.3, axis='y')

# Plot 2: Test ROC-AUC Ranking
ax2 = axes[0, 1]
colors = ['green' if m == best_model_name else 'steelblue' for m in results_df_sorted['Model']]
bars = ax2.barh(results_df_sorted['Model'], results_df_sorted['Test_ROC_AUC'], color=colors)
ax2.axvline(x=0.5, color='red', linestyle='--', label='Random')
ax2.axvline(x=baseline_test_roc, color='orange', linestyle='--', label='Baseline')
ax2.set_xlabel('Test ROC-AUC')
ax2.set_title('Models Ranked by Test ROC-AUC', fontweight='bold')
ax2.legend(loc='lower right')
ax2.set_xlim(0.4, 0.7)
for bar, val in zip(bars, results_df_sorted['Test_ROC_AUC']):
    ax2.text(val + 0.005, bar.get_y() + bar.get_height()/2, f'{val:.3f}', va='center', fontsize=9)

# Plot 3: Generalization Gap
ax3 = axes[0, 2]
gaps = results_df_sorted['Generalization_Gap']
colors = ['red' if g > 0.05 else 'orange' if g > 0 else 'green' for g in gaps]
bars = ax3.barh(results_df_sorted['Model'], gaps, color=colors)
ax3.axvline(x=0, color='black', linestyle='-', linewidth=0.5)
ax3.axvline(x=0.05, color='red', linestyle='--', alpha=0.5, label='Overfitting threshold')
ax3.set_xlabel('Generalization Gap (CV - Test ROC-AUC)')
ax3.set_title('Overfitting Analysis', fontweight='bold')
ax3.legend(loc='lower right')
for bar, val in zip(bars, gaps):
    ax3.text(val + 0.002 if val >= 0 else val - 0.015, bar.get_y() + bar.get_height()/2, 
             f'{val:+.3f}', va='center', fontsize=9)

# Plot 4: Precision vs Recall
ax4 = axes[1, 0]
colors = plt.cm.viridis(np.linspace(0, 1, len(results_df_sorted)))
for i, (_, row) in enumerate(results_df_sorted.iterrows()):
    ax4.scatter(row['Test_Recall'], row['Test_Precision'], s=150, c=[colors[i]], 
                label=row['Model'], alpha=0.8, edgecolors='black')
ax4.set_xlabel('Recall')
ax4.set_ylabel('Precision')
ax4.set_title('Precision vs Recall Trade-off (Test Set)', fontweight='bold')
ax4.legend(loc='upper right', fontsize=8)
ax4.grid(True, alpha=0.3)
ax4.set_xlim(0, 1)
ax4.set_ylim(0, 0.6)

# Plot 5: All Metrics Heatmap
ax5 = axes[1, 1]
metrics_for_heatmap = results_df_sorted[['Model', 'Test_Accuracy', 'Test_Precision', 'Test_Recall', 'Test_F1', 'Test_ROC_AUC']].set_index('Model')
metrics_for_heatmap.columns = ['Accuracy', 'Precision', 'Recall', 'F1', 'ROC-AUC']
sns.heatmap(metrics_for_heatmap, annot=True, fmt='.3f', cmap='YlGnBu', ax=ax5, 
            cbar_kws={'label': 'Score'}, vmin=0, vmax=1)
ax5.set_title('Test Set Metrics Heatmap', fontweight='bold')
ax5.set_ylabel('')

# Plot 6: Improvement Over Baseline
ax6 = axes[1, 2]
improvements = (results_df_sorted['Test_ROC_AUC'] - baseline_test_roc) * 100
colors = ['green' if x > 0 else 'red' for x in improvements]
bars = ax6.barh(results_df_sorted['Model'], improvements, color=colors)
ax6.axvline(x=0, color='black', linestyle='-', linewidth=0.5)
ax6.set_xlabel('Improvement over Baseline (%)')
ax6.set_title('Test ROC-AUC Improvement vs Baseline', fontweight='bold')
for bar, val in zip(bars, improvements):
    ax6.text(val + 0.2 if val >= 0 else val - 1.5, bar.get_y() + bar.get_height()/2, 
             f'{val:+.2f}%', va='center', fontsize=9)

plt.tight_layout()
plt.savefig('data/ml/model_improvement_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Visualization saved to: data/ml/model_improvement_comparison.png")

# ============================================
# STEP 5: SAVE RESULTS AND BEST MODEL
# ============================================

print("\n[Step 5] Saving results...")

# Save detailed results
results_df_sorted.to_csv('data/ml/model_improvement_results.csv', index=False)
print("✓ Results saved to: data/ml/model_improvement_results.csv")

# Save best model
if best_test_roc > baseline_test_roc:
    # Determine which model to save
    if best_model_name == 'Logistic Regression':
        best_model_obj = comparison_models['Logistic Regression']
        # Retrain to ensure it's fitted
        best_model_obj.fit(X_train, y_train)
        joblib.dump(best_model_obj, 'data/ml/best_model_improved.joblib')
        model_type = 'Logistic Regression'
    elif best_model_name == 'RF - Combined':
        joblib.dump(rf_combined_trained, 'data/ml/best_model_improved.joblib')
        pd.DataFrame({'Feature': improved_features}).to_csv('data/ml/feature_columns_improved.csv', index=False)
        model_type = 'Random Forest (Combined)'
    elif best_model_name == 'RF - Tuned':
        joblib.dump(rf_tuned_trained, 'data/ml/best_model_improved.joblib')
        model_type = 'Random Forest (Tuned)'
    elif best_model_name == 'Gradient Boosting':
        best_model_obj = comparison_models['Gradient Boosting']
        best_model_obj.fit(X_train, y_train)
        joblib.dump(best_model_obj, 'data/ml/best_model_improved.joblib')
        model_type = 'Gradient Boosting'
    elif best_model_name == 'RF - Regularized':
        joblib.dump(rf_regularized_trained, 'data/ml/best_model_improved.joblib')
        model_type = 'Random Forest (Regularized)'
    elif best_model_name == 'RF - Improved Features':
        joblib.dump(rf_improved_feat_trained, 'data/ml/best_model_improved.joblib')
        pd.DataFrame({'Feature': improved_features}).to_csv('data/ml/feature_columns_improved.csv', index=False)
        model_type = 'Random Forest (Improved Features)'
    else:
        model_type = 'Unknown'
    
    print(f"✓ Best model ({model_type}) saved to: data/ml/best_model_improved.joblib")
else:
    print("⚠ No improvement over baseline. Keeping original model.")

# ============================================
# STEP 6: FINAL SUMMARY
# ============================================

print("\n" + "="*70)
print("MODEL IMPROVEMENT EXPERIMENTS - FINAL SUMMARY")
print("="*70)

print("\n📋 EXPERIMENTAL METHODOLOGY:")
print("  ✓ All models evaluated with 3-Fold TimeSeriesSplit Cross-Validation")
print("  ✓ All models evaluated on the same held-out test set")
print("  ✓ Same metrics computed for all models")
print("  ✓ Generalization gap calculated to detect overfitting")

print("\n📊 EXPERIMENTS CONDUCTED:")
print("  0. Baseline Random Forest (original configuration)")
print("  1. Improved Features (removed absolute features)")
print("  2. Hyperparameter Tuning (GridSearchCV)")
print("  3. Algorithm Comparison (Logistic Regression, Gradient Boosting, AdaBoost)")
print("  4. Regularized Random Forest (reduced complexity)")
print("  5. Combined Approach (improved features + moderate regularization)")

print(f"\n📈 KEY RESULTS:")
print(f"  Baseline CV ROC-AUC:     {baseline_cv_roc:.4f}")
print(f"  Baseline Test ROC-AUC:   {baseline_test_roc:.4f}")
print(f"  Best Model:              {best_model_name}")
print(f"  Best CV ROC-AUC:         {best_cv_roc:.4f}")
print(f"  Best Test ROC-AUC:       {best_test_roc:.4f}")
print(f"  Improvement:             {(best_test_roc - baseline_test_roc)*100:+.2f}%")

print("\n📁 FILES SAVED:")
print("  - data/ml/model_improvement_results.csv (detailed results)")
print("  - data/ml/model_improvement_comparison.png (visualizations)")
if best_test_roc > baseline_test_roc:
    print("  - data/ml/best_model_improved.joblib (best model)")

print("\n" + "="*70)
print("All experiments completed under identical evaluation conditions")
print("="*70)
# Out:
# ======================================================================
# FYP MODEL IMPROVEMENT EXPERIMENTS (CORRECTED)
# All experiments use identical evaluation conditions
# ======================================================================
#
# [Step 1] Loading data and setting up evaluation framework...
# ✓ Data loaded:
#   Training: (654, 29)
#   Validation: (110, 29)
#   Test: (220, 29)
#   Features: 29
#   Cross-validation: 3-Fold TimeSeriesSplit
#
# [Step 2] Defining standardized evaluation function...
# ✓ Standardized evaluation function defined
#
# ======================================================================
# EXPERIMENT 0: BASELINE RANDOM FOREST
# ======================================================================
#
# Model Configuration:
#   n_estimators: 100
#   max_depth: 10
#   min_samples_leaf: 5
#   class_weight: balanced
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6237 ± 0.0502
#     Precision: 0.3639 ± 0.0669
#     Recall:    0.3317 ± 0.1095
#     F1 Score:  0.3436 ± 0.0906
#     ROC-AUC:   0.6046 ± 0.0785
#
#   Test Set Results:
#     Accuracy:  0.6318
#     Precision: 0.3488
#     Recall:    0.2206
#     F1 Score:  0.2703
#     ROC-AUC:   0.5302
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0744
#     ⚠️ Warning: Significant overfitting detected
#
# ======================================================================
# EXPERIMENT 1: IMPROVED FEATURES
# ======================================================================
#
# Removing absolute features that may cause overfitting:
#   ['Price', 'SMA_50', 'SMA_200', 'Avg_Volume_3M', 'Market_Cap']
#
# Original features: 29
# Improved features: 24
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6196 ± 0.0521
#     Precision: 0.3682 ± 0.0461
#     Recall:    0.3242 ± 0.0839
#     F1 Score:  0.3378 ± 0.0573
#     ROC-AUC:   0.6013 ± 0.0805
#
#   Test Set Results:
#     Accuracy:  0.6500
#     Precision: 0.3953
#     Recall:    0.2500
#     F1 Score:  0.3063
#     ROC-AUC:   0.5546
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0467
#     ✓ Good generalization
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.6013 vs 0.6046 (-0.34%)
#     Test ROC-AUC: 0.5546 vs 0.5302 (+2.44%)
#
# ======================================================================
# EXPERIMENT 2: HYPERPARAMETER TUNING (GridSearchCV)
# ======================================================================
#
# Parameter grid:
#   n_estimators: [50, 100, 150]
#   max_depth: [5, 7, 10]
#   min_samples_leaf: [5, 10, 15]
#   max_features: ['sqrt', 'log2']
#
# Running GridSearchCV with TimeSeriesSplit (this may take a few minutes)...
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
#
# ✓ Best Parameters: {'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'n_estimators': 100}
# ✓ Best CV ROC-AUC: 0.6201
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6074 ± 0.0778
#     Precision: 0.3829 ± 0.0799
#     Recall:    0.4608 ± 0.1114
#     F1 Score:  0.4175 ± 0.0922
#     ROC-AUC:   0.6201 ± 0.0723
#
#   Test Set Results:
#     Accuracy:  0.5818
#     Precision: 0.3421
#     Recall:    0.3824
#     F1 Score:  0.3611
#     ROC-AUC:   0.5505
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0696
#     ⚠️ Warning: Significant overfitting detected
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.6201 vs 0.6046 (+1.55%)
#     Test ROC-AUC: 0.5505 vs 0.5302 (+2.03%)
#
# ======================================================================
# EXPERIMENT 3: ALGORITHM COMPARISON
# ======================================================================
#
# Comparing different ML algorithms under identical conditions...
#
# --- Logistic Regression ---
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.4888 ± 0.0502
#     Precision: 0.3211 ± 0.0076
#     Recall:    0.6020 ± 0.0698
#     F1 Score:  0.4172 ± 0.0161
#     ROC-AUC:   0.5431 ± 0.0243
#
#   Test Set Results:
#     Accuracy:  0.4591
#     Precision: 0.3355
#     Recall:    0.7647
#     F1 Score:  0.4664
#     ROC-AUC:   0.6364
#
#   Generalization Gap (CV - Test ROC-AUC): -0.0934
#     ✓ Good generalization
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.5431 vs 0.6046 (-6.16%)
#     Test ROC-AUC: 0.6364 vs 0.5302 (+10.62%)
#
# --- Gradient Boosting ---
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6626 ± 0.0305
#     Precision: 0.4301 ± 0.0291
#     Recall:    0.2947 ± 0.0434
#     F1 Score:  0.3459 ± 0.0219
#     ROC-AUC:   0.6166 ± 0.0593
#
#   Test Set Results:
#     Accuracy:  0.6591
#     Precision: 0.4000
#     Recall:    0.2059
#     F1 Score:  0.2718
#     ROC-AUC:   0.4973
#
#   Generalization Gap (CV - Test ROC-AUC): 0.1193
#     ⚠️ Warning: Significant overfitting detected
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.6166 vs 0.6046 (+1.20%)
#     Test ROC-AUC: 0.4973 vs 0.5302 (-3.29%)
#
# --- AdaBoost ---
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6564 ± 0.0313
#     Precision: 0.3547 ± 0.1274
#     Recall:    0.2219 ± 0.1145
#     F1 Score:  0.2696 ± 0.1273
#     ROC-AUC:   0.5842 ± 0.0497
#
#   Test Set Results:
#     Accuracy:  0.6909
#     Precision: 0.5000
#     Recall:    0.1765
#     F1 Score:  0.2609
#     ROC-AUC:   0.4928
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0914
#     ⚠️ Warning: Significant overfitting detected
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.5842 vs 0.6046 (-2.04%)
#     Test ROC-AUC: 0.4928 vs 0.5302 (-3.73%)
#
# ======================================================================
# EXPERIMENT 4: REGULARIZED RANDOM FOREST
# ======================================================================
#
# Regularization settings (vs Baseline):
#   n_estimators:     50  (was 100)
#   max_depth:        5   (was 10)
#   min_samples_leaf: 20  (was 5)
#   min_samples_split: 30 (new)
#   max_features:     0.3 (new)
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.5992 ± 0.0676
#     Precision: 0.3735 ± 0.0702
#     Recall:    0.4602 ± 0.0932
#     F1 Score:  0.4123 ± 0.0802
#     ROC-AUC:   0.6036 ± 0.0593
#
#   Test Set Results:
#     Accuracy:  0.5636
#     Precision: 0.3205
#     Recall:    0.3676
#     F1 Score:  0.3425
#     ROC-AUC:   0.5283
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0753
#     ⚠️ Warning: Significant overfitting detected
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.6036 vs 0.6046 (-0.11%)
#     Test ROC-AUC: 0.5283 vs 0.5302 (-0.19%)
#
# ======================================================================
# EXPERIMENT 5: COMBINED IMPROVEMENTS
# ======================================================================
#
# Combining: Improved Features + Moderate Regularization
#
# Combined model settings:
#   Features:         Improved (removed absolute features)
#   n_estimators:     100
#   max_depth:        7   (moderate)
#   min_samples_leaf: 10  (moderate)
#   min_samples_split: 15
#   max_features:     sqrt
#
#   Cross-Validation Results (3-Fold TimeSeriesSplit):
#     Accuracy:  0.6176 ± 0.0654
#     Precision: 0.3816 ± 0.0708
#     Recall:    0.4064 ± 0.1043
#     F1 Score:  0.3918 ± 0.0840
#     ROC-AUC:   0.6197 ± 0.0716
#
#   Test Set Results:
#     Accuracy:  0.6091
#     Precision: 0.3594
#     Recall:    0.3382
#     F1 Score:  0.3485
#     ROC-AUC:   0.5589
#
#   Generalization Gap (CV - Test ROC-AUC): 0.0608
#     ⚠️ Warning: Significant overfitting detected
#
#   Comparison to Baseline:
#     CV ROC-AUC:   0.6197 vs 0.6046 (+1.51%)
#     Test ROC-AUC: 0.5589 vs 0.5302 (+2.87%)
#
# ======================================================================
# COMPREHENSIVE RESULTS COMPARISON
# ======================================================================
#
# ======================================================================
# TABLE 1: CROSS-VALIDATION RESULTS (3-Fold TimeSeriesSplit)
# ======================================================================
#  Rank                  Model Accuracy Precision Recall     F1 ROC-AUC    Std
#     1    Logistic Regression   0.4888    0.3211 0.6020 0.4172  0.5431 0.0243
#     2          RF - Combined   0.6176    0.3816 0.4064 0.3918  0.6197 0.0716
#     3 RF - Improved Features   0.6196    0.3682 0.3242 0.3378  0.6013 0.0805
#     4             RF - Tuned   0.6074    0.3829 0.4608 0.4175  0.6201 0.0723
#     5            Baseline RF   0.6237    0.3639 0.3317 0.3436  0.6046 0.0785
#     6       RF - Regularized   0.5992    0.3735 0.4602 0.4123  0.6036 0.0593
#     7      Gradient Boosting   0.6626    0.4301 0.2947 0.3459  0.6166 0.0593
#     8               AdaBoost   0.6564    0.3547 0.2219 0.2696  0.5842 0.0497
#
# ======================================================================
# TABLE 2: TEST SET RESULTS
# ======================================================================
#  Rank                  Model Accuracy Precision Recall     F1 ROC-AUC vs Baseline
#     1    Logistic Regression   0.4591    0.3355 0.7647 0.4664  0.6364     +10.62%
#     2          RF - Combined   0.6091    0.3594 0.3382 0.3485  0.5589      +2.87%
#     3 RF - Improved Features   0.6500    0.3953 0.2500 0.3063  0.5546      +2.44%
#     4             RF - Tuned   0.5818    0.3421 0.3824 0.3611  0.5505      +2.03%
#     5            Baseline RF   0.6318    0.3488 0.2206 0.2703  0.5302      +0.00%
#     6       RF - Regularized   0.5636    0.3205 0.3676 0.3425  0.5283      -0.19%
#     7      Gradient Boosting   0.6591    0.4000 0.2059 0.2718  0.4973      -3.29%
#     8               AdaBoost   0.6909    0.5000 0.1765 0.2609  0.4928      -3.73%
#
# ======================================================================
# TABLE 3: GENERALIZATION ANALYSIS (Overfitting Detection)
# ======================================================================
#  Rank                  Model CV ROC-AUC Test ROC-AUC Gap (CV - Test)
#     1    Logistic Regression     0.5431       0.6364         -0.0934
#     2          RF - Combined     0.6197       0.5589         +0.0608
#     3 RF - Improved Features     0.6013       0.5546         +0.0467
#     4             RF - Tuned     0.6201       0.5505         +0.0696
#     5            Baseline RF     0.6046       0.5302         +0.0744
#     6       RF - Regularized     0.6036       0.5283         +0.0753
#     7      Gradient Boosting     0.6166       0.4973         +0.1193
#     8               AdaBoost     0.5842       0.4928         +0.0914
#
# Interpretation:
#   - Positive gap: Model performs better on CV than test (overfitting)
#   - Negative gap: Model performs better on test than CV (good generalization)
#   - Gap > 0.05: Significant overfitting concern
#
# ======================================================================
# 🏆 BEST MODEL IDENTIFICATION
# ======================================================================
#
#   Best Model:     Logistic Regression
#   CV ROC-AUC:     0.5431
#   Test ROC-AUC:   0.6364
#   Improvement:    +10.62% over baseline
#
# [Step 4] Creating visualizations...
# ✓ Visualization saved to: data/ml/model_improvement_comparison.png
#
# [Step 5] Saving results...
# ✓ Results saved to: data/ml/model_improvement_results.csv
# ✓ Best model (Logistic Regression) saved to: data/ml/best_model_improved.joblib
#
# ======================================================================
# MODEL IMPROVEMENT EXPERIMENTS - FINAL SUMMARY
# ======================================================================
#
# 📋 EXPERIMENTAL METHODOLOGY:
#   ✓ All models evaluated with 3-Fold TimeSeriesSplit Cross-Validation
#   ✓ All models evaluated on the same held-out test set
#   ✓ Same metrics computed for all models
#   ✓ Generalization gap calculated to detect overfitting
#
# 📊 EXPERIMENTS CONDUCTED:
#   0. Baseline Random Forest (original configuration)
#   1. Improved Features (removed absolute features)
#   2. Hyperparameter Tuning (GridSearchCV)
#   3. Algorithm Comparison (Logistic Regression, Gradient Boosting, AdaBoost)
#   4. Regularized Random Forest (reduced complexity)
#   5. Combined Approach (improved features + moderate regularization)
#
# 📈 KEY RESULTS:
#   Baseline CV ROC-AUC:     0.6046
#   Baseline Test ROC-AUC:   0.5302
#   Best Model:              Logistic Regression
#   Best CV ROC-AUC:         0.5431
#   Best Test ROC-AUC:       0.6364
#   Improvement:             +10.62%
#
# 📁 FILES SAVED:
#   - data/ml/model_improvement_results.csv (detailed results)
#   - data/ml/model_improvement_comparison.png (visualizations)
#   - data/ml/best_model_improved.joblib (best model)
#
# ======================================================================
# All experiments completed under identical evaluation conditions
# ======================================================================

# %%
# ============================================
# SHAP VALUES FOR EXPLAINABILITY
# SHapley Additive exPlanations (Lundberg & Lee, 2017)
# ============================================
# Computes game-theoretic feature attributions for
# every stock prediction made by the Random Forest.
# Replaces hand-coded if-else explanation templates
# with model-derived, per-stock explanations.
#
# Outputs: data/ml/shap_values.csv
#          data/ml/shap_expected_value.txt
#          data/ml/shap_summary.png
#          data/ml/shap_waterfall_<ticker>.png
# ============================================

import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', 'shap', '-q'],
               capture_output=True)

import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import joblib
import os
import warnings
warnings.filterwarnings('ignore')

os.makedirs('data/ml/shap', exist_ok=True)

print("=" * 60)
print("SHAP VALUES FOR EXPLAINABILITY")
print("=" * 60)
print(f"\n✓ SHAP version: {shap.__version__}")
# Out:
# ============================================================
# SHAP VALUES FOR EXPLAINABILITY
# ============================================================
#
# ✓ SHAP version: 0.50.0

# %%
# ============================================
# STEP 1: LOAD MODEL AND FEATURE DATA
# ============================================

print("\n[Step 1] Loading model and data...")

# Load trained Random Forest
rf_model = joblib.load('data/ml/rf_model.joblib')
print(f"✓ Random Forest loaded")
print(f"  Estimators: {rf_model.n_estimators}")
print(f"  Max depth:  {rf_model.max_depth}")

# Load feature columns
feature_cols = pd.read_csv(
    'data/ml/feature_columns.csv')['Feature'].tolist()
print(f"✓ Feature columns: {len(feature_cols)} features")

# Load latest master features (current stocks to explain)
latest_df = pd.read_csv('data/master_features_latest.csv')
print(f"✓ Latest features: {len(latest_df)} stocks")

# Load stock universe for company names
universe = pd.read_csv('data/stock_universe_clean.csv')
if 'Company_Name' not in latest_df.columns:
    latest_df = latest_df.merge(
        universe[['Ticker', 'Company_Name']], on='Ticker', how='left')

# Load training data (for SHAP background distribution)
train_df = pd.read_csv('data/ml/train_data.csv')
print(f"✓ Training data: {len(train_df)} rows")

# ---- Prepare features (with sector one-hot encoding) ----
def prepare_features(df, feature_cols):
    df = df.copy()
    if 'Sector' in df.columns:
        dummies = pd.get_dummies(df['Sector'], prefix='Sector')
        df = pd.concat([df, dummies], axis=1)
    for col in feature_cols:
        if col.startswith('Sector_') and col not in df.columns:
            df[col] = 0
    X = df[feature_cols].copy()
    X = X.fillna(X.median())
    return X

X_latest = prepare_features(latest_df, feature_cols)
X_train  = prepare_features(train_df,  feature_cols)

print(f"\n✓ Feature matrices ready:")
print(f"  X_latest: {X_latest.shape}")
print(f"  X_train:  {X_train.shape}")

# Verify all columns match
assert list(X_latest.columns) == list(X_train.columns) == feature_cols, \
    "Feature column mismatch — check encoding"
print("✓ Feature column alignment verified")
# Out:
# [Step 1] Loading model and data...
# ✓ Random Forest loaded
#   Estimators: 100
#   Max depth:  10
# ✓ Feature columns: 29 features
# ✓ Latest features: 55 stocks
# ✓ Training data: 654 rows
#
# ✓ Feature matrices ready:
#   X_latest: (55, 29)
#   X_train:  (654, 29)
# ✓ Feature column alignment verified

# %%
# ============================================
# STEP 2: COMPUTE SHAP VALUES
# ============================================
# TreeExplainer is the correct explainer for
# Random Forest — it is exact (not approximate)
# and runs in polynomial time using the tree
# structure directly.
# ============================================

print("\n[Step 2] Computing SHAP values...")
print("  Using TreeExplainer (exact, polynomial time)")

# Use training data as background for SHAP baseline
# 100 samples is sufficient and fast
background = shap.sample(X_train, 100, random_state=42)

# Initialise TreeExplainer
explainer = shap.TreeExplainer(
    rf_model,
    data=background,
    feature_perturbation='interventional',
    model_output='probability'
)

print("✓ TreeExplainer initialised")
print("  Computing SHAP values for all current stocks...")

# Compute SHAP values for all latest stocks
# shap_values shape: (n_stocks, n_features, n_classes)
# We want class 1 (probability of outperforming)
shap_values_all = explainer.shap_values(X_latest)

# For RandomForestClassifier, shap_values returns a list [class0, class1]
if isinstance(shap_values_all, list):
    # List format: [class0_array, class1_array]
    shap_vals = shap_values_all[1]
elif isinstance(shap_values_all, np.ndarray) and shap_values_all.ndim == 3:
    # 3D array format: (n_stocks, n_features, n_classes)
    shap_vals = shap_values_all[:, :, 1]
else:
    shap_vals = shap_values_all

# Safety check — shap_vals must be 2D (n_stocks, n_features)
print(f"  shap_vals shape: {shap_vals.shape}")
assert shap_vals.ndim == 2, \
    f"Expected 2D array, got shape {shap_vals.shape}"
assert shap_vals.shape[0] == len(X_latest), \
    f"Row count mismatch: {shap_vals.shape[0]} vs {len(X_latest)} stocks"

expected_value = (explainer.expected_value[1]
                  if isinstance(explainer.expected_value, (list, np.ndarray))
                  else explainer.expected_value)

print(f"\n✓ SHAP values computed:")
print(f"  Shape: {shap_vals.shape}  "
      f"(stocks × features)")
print(f"  Expected value (base rate): {expected_value:.4f}")
print(f"  This means the model's average predicted outperform "
      f"probability is {expected_value:.1%}")

# Quick sanity check: SHAP values + expected value
# should approximately equal the model's predicted probabilities
ml_probs  = rf_model.predict_proba(X_latest)[:, 1]
shap_preds = shap_vals.sum(axis=1) + expected_value
correlation = np.corrcoef(ml_probs, shap_preds)[0, 1]
print(f"\n✓ Sanity check — correlation between "
      f"SHAP-reconstructed and actual probabilities: {correlation:.4f}")
if correlation > 0.99:
    print("  ✓ Excellent — SHAP values are consistent with model output")
elif correlation > 0.95:
    print("  ✓ Good — minor floating point differences")
else:
    print("  ⚠ Unexpected deviation — check explainer settings")
# Out:
# [Step 2] Computing SHAP values...
#   Using TreeExplainer (exact, polynomial time)
# ✓ TreeExplainer initialised
#   Computing SHAP values for all current stocks...
#   shap_vals shape: (55, 29)
#
# ✓ SHAP values computed:
#   Shape: (55, 29)  (stocks × features)
#   Expected value (base rate): 0.3891
#   This means the model's average predicted outperform probability is 38.9%
#
# ✓ Sanity check — correlation between SHAP-reconstructed and actual probabilities: 1.0000
#   ✓ Excellent — SHAP values are consistent with model output

# %%
# ============================================
# STEP 3: SAVE SHAP VALUES TO CSV
# ============================================

print("\n[Step 3] Saving SHAP values...")

# Build SHAP dataframe (one row per stock, one col per feature)
shap_df = pd.DataFrame(
    shap_vals,
    columns=[f'SHAP_{col}' for col in feature_cols]
)

# Add identifiers
shap_df.insert(0, 'Ticker', latest_df['Ticker'].values)
if 'Company_Name' in latest_df.columns:
    shap_df.insert(1, 'Company_Name', latest_df['Company_Name'].values)

# Add model probability and SHAP sum for verification
shap_df['ML_Probability']   = ml_probs
shap_df['SHAP_Sum']         = shap_vals.sum(axis=1)
shap_df['SHAP_Reconstructed'] = shap_vals.sum(axis=1) + expected_value

# Save
shap_df.to_csv('data/ml/shap_values.csv', index=False)

# Save expected value separately (needed by app.py)
with open('data/ml/shap_expected_value.txt', 'w') as f:
    f.write(str(expected_value))

print(f"✓ Saved: data/ml/shap_values.csv")
print(f"  Rows: {len(shap_df)} stocks")
print(f"  Cols: {len(shap_df.columns)} "
      f"(2 ID + {len(feature_cols)} SHAP + 3 metadata)")
print(f"✓ Saved: data/ml/shap_expected_value.txt  "
      f"(expected value = {expected_value:.6f})")

# Preview top stocks by ML probability
print("\nTop 5 stocks by ML predicted probability:")
preview = shap_df[['Ticker', 'Company_Name', 'ML_Probability']].copy()
preview = preview.sort_values('ML_Probability', ascending=False).head(5)
print(preview.to_string(index=False))
# Out:
# [Step 3] Saving SHAP values...
# ✓ Saved: data/ml/shap_values.csv
#   Rows: 55 stocks
#   Cols: 34 (2 ID + 29 SHAP + 3 metadata)
# ✓ Saved: data/ml/shap_expected_value.txt  (expected value = 0.389145)
#
# Top 5 stocks by ML predicted probability:
#  Ticker           Company_Name  ML_Probability
#  BS6.SI       YZJ Shipbldg SGD        0.717803
#  QC7.SI         Cordlife Group        0.643825
#  U77.SI     Yanlord Land Group        0.625702
# CMOU.SI CapitaLand China Trust        0.569938
#  C41.SI             Olam Group        0.560420

# %%
# ============================================
# STEP 4: GLOBAL SHAP SUMMARY PLOTS
# ============================================
# Shows which features matter most across ALL
# stocks — the global view of model behaviour.
# ============================================

print("\n[Step 4] Generating global SHAP summary plots...")

DARK_BG  = '#0d1b2a'
CARD_BG  = '#162435'
GREEN    = '#00b894'
AMBER    = '#fdcb6e'
RED      = '#e17055'
MUTED    = '#8fa3b1'

# ---- Plot 1: Bar plot — mean absolute SHAP per feature ----
mean_abs_shap = np.abs(shap_vals).mean(axis=0)
feature_importance_shap = pd.DataFrame({
    'Feature':    feature_cols,
    'Mean_Abs_SHAP': mean_abs_shap
}).sort_values('Mean_Abs_SHAP', ascending=False)

# Show top 15 features
top15 = feature_importance_shap.head(15)

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
fig.patch.set_facecolor(DARK_BG)

# Bar chart
ax1 = axes[0]
ax1.set_facecolor(CARD_BG)
bars = ax1.barh(
    top15['Feature'][::-1],
    top15['Mean_Abs_SHAP'][::-1],
    color=GREEN, alpha=0.85
)
ax1.set_xlabel('Mean |SHAP Value|', color='white', fontsize=11)
ax1.set_title('Top 15 Features by Global SHAP Importance\n'
              '(Mean Absolute Impact on Predicted Probability)',
              color='white', fontweight='bold', fontsize=11)
ax1.tick_params(colors='white')
ax1.spines[:].set_color('#2d4a63')

# Add value labels
for bar, val in zip(bars, top15['Mean_Abs_SHAP'][::-1]):
    ax1.text(val + 0.0005, bar.get_y() + bar.get_height() / 2,
             f'{val:.4f}', va='center', color='white', fontsize=8)

# SHAP beeswarm / dot summary using matplotlib manually
ax2 = axes[1]
ax2.set_facecolor(CARD_BG)

# Get top 10 features for dot plot
top10_features = feature_importance_shap.head(10)['Feature'].tolist()
top10_indices  = [feature_cols.index(f) for f in top10_features]

for y_pos, (feat_idx, feat_name) in enumerate(
        zip(top10_indices, top10_features)):
    shap_col  = shap_vals[:, feat_idx]
    feat_col  = X_latest.iloc[:, feat_idx].values

    # Normalise feature values to [0, 1] for colour mapping
    feat_min, feat_max = feat_col.min(), feat_col.max()
    feat_norm = ((feat_col - feat_min) / (feat_max - feat_min + 1e-9))

    # Jitter y position
    y_jitter = y_pos + np.random.uniform(-0.3, 0.3, len(shap_col))
    colors   = plt.cm.RdYlGn(feat_norm)

    ax2.scatter(shap_col, y_jitter, c=colors, alpha=0.6, s=20, zorder=2)

ax2.axvline(0, color='white', linewidth=0.8, alpha=0.5)
ax2.set_yticks(range(len(top10_features)))
ax2.set_yticklabels(top10_features, color='white', fontsize=9)
ax2.set_xlabel('SHAP Value\n(positive = increases outperform probability)',
               color='white', fontsize=10)
ax2.set_title('SHAP Distribution per Feature\n'
              '(colour: 🔴 low feature value → 🟢 high feature value)',
              color='white', fontweight='bold', fontsize=11)
ax2.tick_params(colors='white')
ax2.spines[:].set_color('#2d4a63')

# Colour bar legend
sm = plt.cm.ScalarMappable(cmap='RdYlGn',
                            norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax2, shrink=0.6)
cbar.set_label('Feature value (normalised)', color='white', fontsize=8)
cbar.ax.yaxis.set_tick_params(color='white')
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

plt.suptitle('SHAP Global Feature Importance — SGX Stock Advisor RF Model',
             color='white', fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('data/ml/shap/shap_summary.png',
            dpi=150, bbox_inches='tight', facecolor=DARK_BG)
plt.show()
print("✓ Saved: data/ml/shap/shap_summary.png")

# Also save SHAP feature importance ranking
feature_importance_shap.to_csv(
    'data/ml/shap/shap_feature_importance.csv', index=False)
print("✓ Saved: data/ml/shap/shap_feature_importance.csv")
print(f"\nTop 10 features by SHAP importance:")
print(feature_importance_shap.head(10).to_string(index=False))
# Out:
# [Step 4] Generating global SHAP summary plots...
# ✓ Saved: data/ml/shap/shap_summary.png
# ✓ Saved: data/ml/shap/shap_feature_importance.csv
#
# Top 10 features by SHAP importance:
#       Feature  Mean_Abs_SHAP
#           EPS       0.028809
#           ROE       0.024546
#        SMA_50       0.019751
# Profit_Margin       0.015372
# Avg_Volume_3M       0.013594
#          High       0.012795
#         Price       0.012000
#           Low       0.011876
#          Open       0.009301
#      PE_Ratio       0.009226

# %%
# ============================================
# STEP 5: PER-STOCK WATERFALL CHARTS
# ============================================
# Shows exactly WHY the model rated each stock
# the way it did — the local explanation.
# Generates charts for top 5 and bottom 5 stocks.
# ============================================

print("\n[Step 5] Generating per-stock waterfall charts...")

# Get top 5 and bottom 5 by ML probability
latest_with_shap = latest_df.copy()
latest_with_shap['ML_Probability'] = ml_probs

top5_stocks    = latest_with_shap.nlargest(5,  'ML_Probability')
bottom5_stocks = latest_with_shap.nsmallest(5, 'ML_Probability')
stocks_to_plot = pd.concat([top5_stocks, bottom5_stocks])

print(f"  Generating waterfall charts for "
      f"{len(stocks_to_plot)} stocks...")


def plot_waterfall(ticker, company_name, shap_row,
                   feature_values_row, ml_prob, expected_val,
                   top_n=10, save=True):
    """
    Plot a waterfall chart showing the top contributing features
    for a single stock's ML prediction.
    """
    DARK_BG = '#0d1b2a'
    CARD_BG = '#162435'
    GREEN   = '#00b894'
    RED     = '#e17055'
    MUTED   = '#8fa3b1'

    # Sort by absolute SHAP value, keep top_n
    abs_shap   = np.abs(shap_row)
    top_idx    = np.argsort(abs_shap)[::-1][:top_n]
    top_feats  = [feature_cols[i] for i in top_idx]
    top_shap   = [shap_row[i]     for i in top_idx]
    top_vals   = [feature_values_row[i] for i in top_idx]

    # Reverse for bottom-to-top waterfall
    top_feats = top_feats[::-1]
    top_shap  = top_shap[::-1]
    top_vals  = top_vals[::-1]

    fig, ax = plt.subplots(figsize=(10, 6))
    fig.patch.set_facecolor(DARK_BG)
    ax.set_facecolor(CARD_BG)

    colors = [GREEN if v > 0 else RED for v in top_shap]

    bars = ax.barh(range(len(top_feats)), top_shap,
                   color=colors, alpha=0.85, height=0.6)

    ax.axvline(0, color='white', linewidth=0.8, alpha=0.6)

    # Feature labels with actual values
    y_labels = []
    for feat, val in zip(top_feats, top_vals):
        feat_short = feat.replace('Sector_', 'Sector: ')
        if abs(val) < 1 and abs(val) > 0.001:
            val_str = f'{val:.3f}'
        elif abs(val) >= 1:
            val_str = f'{val:.2f}'
        else:
            val_str = f'{val:.2e}'
        y_labels.append(f'{feat_short}  [{val_str}]')

    ax.set_yticks(range(len(top_feats)))
    ax.set_yticklabels(y_labels, color='white', fontsize=8.5)

    # Value labels on bars
    for bar, val in zip(bars, top_shap):
        x_pos = val + 0.001 if val >= 0 else val - 0.001
        ha    = 'left'       if val >= 0 else 'right'
        ax.text(x_pos, bar.get_y() + bar.get_height() / 2,
                f'{val:+.4f}', va='center', ha=ha,
                color='white', fontsize=8)

    # Base rate and prediction annotations
    ax.set_xlabel('SHAP Value (impact on predicted probability)',
                  color='white', fontsize=10)
    ax.set_title(
        f'{company_name} ({ticker})\n'
        f'ML Prediction: {ml_prob:.1%} outperform probability  '
        f'│  Base rate: {expected_val:.1%}',
        color='white', fontweight='bold', fontsize=11
    )
    ax.tick_params(colors='white')
    ax.spines[:].set_color('#2d4a63')

    # Legend
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor=GREEN, label='↑ Increases predicted probability'),
        Patch(facecolor=RED,   label='↓ Decreases predicted probability'),
    ]
    ax.legend(handles=legend_elements,
              facecolor='#1e2d3d', labelcolor='white', fontsize=8,
              loc='lower right')

    plt.tight_layout()

    if save:
        safe_ticker = ticker.replace('.', '_')
        path = f'data/ml/shap/waterfall_{safe_ticker}.png'
        plt.savefig(path, dpi=130, bbox_inches='tight',
                    facecolor=DARK_BG)
        plt.close(fig)
        return path
    else:
        plt.show()
        plt.close(fig)
        return None


# Generate and save waterfall charts
saved_charts = []
for _, stock_row in stocks_to_plot.iterrows():
    ticker   = stock_row['Ticker']
    company  = stock_row.get('Company_Name', ticker)
    prob     = stock_row['ML_Probability']

    # Find index in X_latest
    match_idx = latest_df[latest_df['Ticker'] == ticker].index
    if len(match_idx) == 0:
        continue
    row_idx = latest_df.index.get_loc(match_idx[0])

    shap_row         = shap_vals[row_idx]
    feature_vals_row = X_latest.iloc[row_idx].values

    path = plot_waterfall(
        ticker, company, shap_row,
        feature_vals_row, prob, expected_value
    )
    saved_charts.append((ticker, company, prob, path))
    status = '🟢 TOP' if prob >= 0.5 else '🔴 BOTTOM'
    print(f"  {status}  {ticker:12s}  {company:30s}  "
          f"prob={prob:.1%}  → {path}")

print(f"\n✓ {len(saved_charts)} waterfall charts saved to data/ml/shap/")
# Out:
# [Step 5] Generating per-stock waterfall charts...
#   Generating waterfall charts for 10 stocks...
#   🟢 TOP  BS6.SI        YZJ Shipbldg SGD                prob=71.8%  → data/ml/shap/waterfall_BS6_SI.png
#   🟢 TOP  QC7.SI        Cordlife Group                  prob=64.4%  → data/ml/shap/waterfall_QC7_SI.png
#   🟢 TOP  U77.SI        Yanlord Land Group              prob=62.6%  → data/ml/shap/waterfall_U77_SI.png
#   🟢 TOP  CMOU.SI       CapitaLand China Trust          prob=57.0%  → data/ml/shap/waterfall_CMOU_SI.png
#   🟢 TOP  C41.SI        Olam Group                      prob=56.0%  → data/ml/shap/waterfall_C41_SI.png
#   🔴 BOTTOM  C38U.SI       CapitaLand Ascendas REIT        prob=10.8%  → data/ml/shap/waterfall_C38U_SI.png
#   🔴 BOTTOM  ME8U.SI       Mapletree Industrial Trust      prob=11.3%  → data/ml/shap/waterfall_ME8U_SI.png
#   🔴 BOTTOM  AJBU.SI       Keppel Infrastructure Trust     prob=14.9%  → data/ml/shap/waterfall_AJBU_SI.png
#   🔴 BOTTOM  CC3.SI        StarHub                         prob=15.3%  → data/ml/shap/waterfall_CC3_SI.png
#   🔴 BOTTOM  J69U.SI       Mapletree Logistics Trust       prob=15.7%  → data/ml/shap/waterfall_J69U_SI.png
#
# ✓ 10 waterfall charts saved to data/ml/shap/

# %%
# ============================================
# STEP 6: SHAP vs RF FEATURE IMPORTANCE
#         COMPARISON
# ============================================
# Compares SHAP's model-derived importance
# against Random Forest's built-in impurity-based
# feature importance — a key analysis for the report.
# ============================================

print("\n[Step 6] Comparing SHAP vs RF feature importance...")

# Load RF built-in importance (saved in FYP_Development.ipynb)
rf_importance_path = 'data/ml/feature_importance.csv'
if os.path.exists(rf_importance_path):
    rf_imp_df = pd.read_csv(rf_importance_path)
    # Standardise column names
    if 'Importance' not in rf_imp_df.columns:
        rf_imp_df.columns = ['Feature', 'Importance']
else:
    # Recompute from model
    rf_imp_df = pd.DataFrame({
        'Feature':    feature_cols,
        'Importance': rf_model.feature_importances_
    })

# Merge with SHAP importance
comparison_df = feature_importance_shap.rename(
    columns={'Mean_Abs_SHAP': 'SHAP_Importance'}).merge(
    rf_imp_df.rename(columns={'Importance': 'RF_Importance'}),
    on='Feature', how='inner'
)

# Normalise both to [0, 1] for fair comparison
comparison_df['SHAP_Norm'] = (
    comparison_df['SHAP_Importance'] /
    comparison_df['SHAP_Importance'].max()
)
comparison_df['RF_Norm'] = (
    comparison_df['RF_Importance'] /
    comparison_df['RF_Importance'].max()
)

# Rank correlation
from scipy.stats import spearmanr
corr, pval = spearmanr(
    comparison_df['SHAP_Importance'],
    comparison_df['RF_Importance']
)
print(f"\n  Spearman rank correlation: {corr:.4f}  (p={pval:.4f})")
if corr > 0.8:
    print("  ✓ High agreement — both methods identify similar features")
elif corr > 0.5:
    print("  ⚠ Moderate agreement — some differences in feature ranking")
else:
    print("  ✗ Low agreement — SHAP reveals different patterns than RF importance")

# Plot comparison
top_n = 15
top_feats_comp = comparison_df.nlargest(top_n, 'SHAP_Importance')

fig, ax = plt.subplots(figsize=(12, 7))
fig.patch.set_facecolor(DARK_BG)
ax.set_facecolor(CARD_BG)

x      = np.arange(len(top_feats_comp))
width  = 0.35
bars1  = ax.bar(x - width/2, top_feats_comp['SHAP_Norm'],
                width, label='SHAP Importance',
                color='#00b894', alpha=0.85)
bars2  = ax.bar(x + width/2, top_feats_comp['RF_Norm'],
                width, label='RF Impurity Importance',
                color='#6c5ce7', alpha=0.85)

ax.set_xticks(x)
ax.set_xticklabels(top_feats_comp['Feature'],
                   rotation=45, ha='right', color='white', fontsize=8)
ax.set_ylabel('Normalised Importance', color='white', fontsize=10)
ax.set_title(
    f'SHAP vs RF Built-in Feature Importance\n'
    f'(Spearman ρ = {corr:.3f}, p = {pval:.4f})',
    color='white', fontweight='bold', fontsize=12
)
ax.legend(facecolor='#1e2d3d', labelcolor='white', fontsize=9)
ax.tick_params(colors='white')
ax.spines[:].set_color('#2d4a63')

plt.tight_layout()
plt.savefig('data/ml/shap/shap_vs_rf_importance.png',
            dpi=150, bbox_inches='tight', facecolor=DARK_BG)
plt.show()
print("✓ Saved: data/ml/shap/shap_vs_rf_importance.png")

# Save comparison table
comparison_df.sort_values(
    'SHAP_Importance', ascending=False
).to_csv('data/ml/shap/shap_vs_rf_comparison.csv', index=False)
print("✓ Saved: data/ml/shap/shap_vs_rf_comparison.csv")
# Out:
# [Step 6] Comparing SHAP vs RF feature importance...
#
#   Spearman rank correlation: 0.5877  (p=0.0008)
#   ⚠ Moderate agreement — some differences in feature ranking
# ✓ Saved: data/ml/shap/shap_vs_rf_importance.png
# ✓ Saved: data/ml/shap/shap_vs_rf_comparison.csv

# %%
# ============================================
# STEP 7: FINAL SUMMARY
# ============================================

print("\n" + "=" * 60)
print("SHAP EXPLAINABILITY — COMPLETE")
print("=" * 60)

print(f"\n📊 GLOBAL INSIGHTS:")
print(f"  Top 5 features by SHAP importance:")
for _, row in feature_importance_shap.head(5).iterrows():
    print(f"    {row['Feature']:30s}  {row['Mean_Abs_SHAP']:.5f}")

print(f"\n  Base rate (expected value): {expected_value:.4f} "
      f"({expected_value:.1%} average outperform probability)")
print(f"  Spearman correlation (SHAP vs RF): {corr:.4f}")

print(f"\n📁 FILES SAVED:")
print(f"  data/ml/shap_values.csv              ← per-stock SHAP values")
print(f"  data/ml/shap_expected_value.txt      ← model base rate")
print(f"  data/ml/shap/shap_summary.png")
print(f"  data/ml/shap/shap_feature_importance.csv")
print(f"  data/ml/shap/shap_vs_rf_importance.png")
print(f"  data/ml/shap/shap_vs_rf_comparison.csv")
print(f"  data/ml/shap/waterfall_<ticker>.png  "
      f"× {len(saved_charts)} stocks")

print(f"\n✅ NEXT STEP:")
print(f"  Update app.py to load data/ml/shap_values.csv")
print(f"  and replace the if-else explanation templates")
print(f"  in generate_stock_explanation() with SHAP-derived text.")

print("\n" + "=" * 60)
# Out:
# ============================================================
# SHAP EXPLAINABILITY — COMPLETE
# ============================================================
#
# 📊 GLOBAL INSIGHTS:
#   Top 5 features by SHAP importance:
#     EPS                             0.02881
#     ROE                             0.02455
#     SMA_50                          0.01975
#     Profit_Margin                   0.01537
#     Avg_Volume_3M                   0.01359
#
#   Base rate (expected value): 0.3891 (38.9% average outperform probability)
#   Spearman correlation (SHAP vs RF): 0.5877
#
# 📁 FILES SAVED:
#   data/ml/shap_values.csv              ← per-stock SHAP values
#   data/ml/shap_expected_value.txt      ← model base rate
#   data/ml/shap/shap_summary.png
#   data/ml/shap/shap_feature_importance.csv
#   data/ml/shap/shap_vs_rf_importance.png
#   data/ml/shap/shap_vs_rf_comparison.csv
#   data/ml/shap/waterfall_<ticker>.png  × 10 stocks
#
# ✅ NEXT STEP:
#   Update app.py to load data/ml/shap_values.csv
#   and replace the if-else explanation templates
#   in generate_stock_explanation() with SHAP-derived text.
#
# ============================================================
